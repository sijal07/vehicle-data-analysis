# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("electric_vehicles_spec_2025.csv")

# %%
df.head()
# Out:
#     brand                model  top_speed_kmh  battery_capacity_kWh  \
# 0  Abarth     500e Convertible            155                  37.8
# 1  Abarth       500e Hatchback            155                  37.8
# 2  Abarth  600e Scorpionissima            200                  50.8
# 3  Abarth         600e Turismo            200                  50.8
# 4  Aiways                   U5            150                  60.0
#
#   battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 0  Lithium-ion            192.0      235.0                   156       225
# 1  Lithium-ion            192.0      235.0                   149       225
# 2  Lithium-ion            102.0      345.0                   158       280
# 3  Lithium-ion            102.0      345.0                   158       280
# 4  Lithium-ion              NaN      310.0                   156       315
#
#    acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# ...

# %%
df.drop(['source_url','model', 'brand','segment','cargo_volume_l'], axis=1, inplace=True)

# %%
cat= ['battery_type','drivetrain', 'car_body_type', 'fast_charge_port']
for i in cat:
    df[i] = LabelEncoder().fit_transform(df[i])

# %%
df.head()
# Out:
#    top_speed_kmh  battery_capacity_kWh  battery_type  number_of_cells  \
# 0            155                  37.8             0            192.0
# 1            155                  37.8             0            192.0
# 2            200                  50.8             0            102.0
# 3            200                  50.8             0            102.0
# 4            150                  60.0             0              NaN
#
#    torque_nm  efficiency_wh_per_km  range_km  acceleration_0_100_s  \
# 0      235.0                   156       225                   7.0
# 1      235.0                   149       225                   7.0
# 2      345.0                   158       280                   5.9
# 3      345.0                   158       280                   6.2
# 4      310.0                   156       315                   7.5
#
#    fast_charging_power_kw_dc  fast_charge_port  towing_capacity_kg  seats  \
# ...

# %%
df.isnull().sum()
# Out:
# top_speed_kmh                  0
# battery_capacity_kWh           0
# battery_type                   0
# number_of_cells              202
# torque_nm                      7
# efficiency_wh_per_km           0
# range_km                       0
# acceleration_0_100_s           0
# fast_charging_power_kw_dc      1
# fast_charge_port               0
# towing_capacity_kg            26
# seats                          0
# drivetrain                     0
# length_mm                      0
# width_mm                       0
# height_mm                      0
# car_body_type                  0
# dtype: int64

# %%
df['number_of_cells'].fillna(df['number_of_cells'].mean(), inplace=True)
df['torque_nm'].fillna(df['torque_nm'].mean(), inplace=True)
df['fast_charging_power_kw_dc'].fillna(df['fast_charging_power_kw_dc'].mean(), inplace=True)
df['towing_capacity_kg'].fillna(df['towing_capacity_kg'].mean(), inplace=True)
# Out:
# C:\Users\salil\AppData\Local\Temp\ipykernel_12668\3069689392.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['number_of_cells'].fillna(df['number_of_cells'].mean(), inplace=True)
# C:\Users\salil\AppData\Local\Temp\ipykernel_12668\3069689392.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.head()
# Out:
#    top_speed_kmh  battery_capacity_kWh  battery_type  number_of_cells  \
# 0            155                  37.8             0       192.000000
# 1            155                  37.8             0       192.000000
# 2            200                  50.8             0       102.000000
# 3            200                  50.8             0       102.000000
# 4            150                  60.0             0       485.293478
#
#    torque_nm  efficiency_wh_per_km  range_km  acceleration_0_100_s  \
# 0      235.0                   156       225                   7.0
# 1      235.0                   149       225                   7.0
# 2      345.0                   158       280                   5.9
# 3      345.0                   158       280                   6.2
# 4      310.0                   156       315                   7.5
#
#    fast_charging_power_kw_dc  fast_charge_port  towing_capacity_kg  seats  \
# ...

# %%
df.isnull().sum()
# Out:
# top_speed_kmh                0
# battery_capacity_kWh         0
# battery_type                 0
# number_of_cells              0
# torque_nm                    0
# efficiency_wh_per_km         0
# range_km                     0
# acceleration_0_100_s         0
# fast_charging_power_kw_dc    0
# fast_charge_port             0
# towing_capacity_kg           0
# seats                        0
# drivetrain                   0
# length_mm                    0
# width_mm                     0
# height_mm                    0
# car_body_type                0
# dtype: int64

# %%
X = df.drop('efficiency_wh_per_km', axis=1)
y = df['efficiency_wh_per_km']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train.head()
# Out:
#      top_speed_kmh  battery_capacity_kWh  battery_type  number_of_cells  \
# 206            170                  47.1             0       485.293478
# 263            170                  49.2             0       485.293478
# 198            200                  74.4             0       485.293478
# 276            200                  90.0             0        96.000000
# 377            150                  81.0             0       485.293478
#
#      torque_nm  range_km  acceleration_0_100_s  fast_charging_power_kw_dc  \
# 206      250.0       275                   8.0                       80.0
# 263      330.0       330                   6.7                       75.0
# 198      725.0       395                   3.2                       85.0
# 276      850.0       505                   3.8                      100.0
# 377      320.0       390                   9.6                       50.0
#
#      fast_charge_port  towing_capacity_kg  seats  drivetrain  length_mm  \
# ...

# %%
y_train.head()
# Out:
# 206    139
# 263    127
# 198    168
# 276    178
# 377    166
# Name: efficiency_wh_per_km, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# Linear Regression
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Decision Tree
tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(X_train, y_train)
# Random Forest
forest_reg = RandomForestRegressor(random_state=42)
forest_reg.fit(X_train, y_train)
# Predict using training data
lin_preds = lin_reg.predict(X_train)
tree_preds = tree_reg.predict(X_train)
forest_preds = forest_reg.predict(X_train)

# %%
from sklearn.metrics import r2_score
lin=r2_score(y_train, lin_preds)

# %%
from sklearn.metrics import r2_score
tree= r2_score(y_train, tree_preds)

# %%
from sklearn.metrics import r2_score
forest= r2_score(y_train, forest_preds)

# %%
print("Linear Regression :", lin)
print("Decision Tree :", tree)
print("Random Forest :", forest)
# Out:
# Linear Regression : 0.7227359147793742
# Decision Tree : 0.9994916293290727
# Random Forest : 0.9843733688522263

# %%
print("by Decision Tree :")



print("efficiency_wh_per_km  =", tree_reg.predict([[200 ,47.1, 0, 485.293478, 250.0,275, 8.0, 80.0,	0, 750.000000, 5, 2, 4476, 2000, 1621,  2]]))
# Out:
# by Decision Tree :
# efficiency_wh_per_km  = [121.]
# c:\Users\salil\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X_train["range_km"],tree_preds )

plt.xlabel("range_km")
plt.ylabel("efficiency_wh_per_km")
plt.title(" r vs e")
plt.show()

# %%
import matplotlib.pyplot as plt


for_c = np.array(tree_preds)


plt.scatter(X_train["torque_nm"],tree_preds , c=for_c, cmap='PiYG'  ,alpha=0.5,  )
plt.colorbar(label='Score')
plt.xlabel("torque_nm")
plt.ylabel("efficiency_wh_per_km")
plt.title(" t vs e")
plt.show()

# %%
from pandas.plotting import scatter_matrix
attributes = [ "top_speed_kmh", "battery_capacity_kWh", "torque_nm","range_km"]
scatter_matrix(X_train[attributes], figsize=(12, 8))
plt.show()

# %%
df.plot(kind="scatter", x="top_speed_kmh", y="acceleration_0_100_s", 
grid=True)
# Out:
# <Axes: xlabel='top_speed_kmh', ylabel='acceleration_0_100_s'>

# %%
import matplotlib.pyplot as plt
import numpy as np
label= df["efficiency_wh_per_km"]
bins = [100, 150, 200, 250, 300, 350]
plt.hist(label, bins=bins, edgecolor='black',color='cyan')
plt.axvline (np.mean(label), color='red', linestyle='--', linewidth=2, label='Average fficiency_wh_per_km ')
plt.title('efficiency_wh_per_km')
plt.xlabel('efficiency_wh_per_km')
plt.ylabel('bins')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# %%
scores_normalized = np.array(tree_preds)
plt.scatter(y_train, tree_preds, c=scores_normalized, cmap='viridis')
plt.colorbar(label='Score')
plt.title('Scatter Plot with Colormap')
plt.xlabel('y')
plt.ylabel('pred')
plt.grid(True)
plt.show()

# %%
plt.subplot(1, 2, 1) # (rows, cols, plot_no)
fb = np.array(lin_preds)
plt.scatter(y_train, lin_preds, c=fb, cmap='jet')
plt.colorbar(label='Score')
plt.title('lin_preds')
plt.subplot(1, 2, 2)
sb = np.array(tree_preds)
plt.scatter(y_train, tree_preds, c=sb, cmap='viridis')
plt.colorbar(label='Score')
plt.title('tree_preds')
plt.tight_layout()
plt.show()

# %%
df.to_csv("new_data.csv", index=False)

# %%
dataset = pd.read_csv('new_data.csv')
a = dataset.drop('drivetrain', axis=1)
b = dataset['drivetrain']

# %%
dataset.head()
# Out:
#    top_speed_kmh  battery_capacity_kWh  battery_type  number_of_cells  \
# 0            155                  37.8             0       192.000000
# 1            155                  37.8             0       192.000000
# 2            200                  50.8             0       102.000000
# 3            200                  50.8             0       102.000000
# 4            150                  60.0             0       485.293478
#
#    torque_nm  efficiency_wh_per_km  range_km  acceleration_0_100_s  \
# 0      235.0                   156       225                   7.0
# 1      235.0                   149       225                   7.0
# 2      345.0                   158       280                   5.9
# 3      345.0                   158       280                   6.2
# 4      310.0                   156       315                   7.5
#
#    fast_charging_power_kw_dc  fast_charge_port  towing_capacity_kg  seats  \
# ...

# %%
from sklearn.model_selection import train_test_split
a_train, a_test, b_train, b_test = train_test_split(a, b, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
a_train= sc.fit_transform(a_train)
a_test= sc.fit_transform(a_test)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
a_train = pca.fit_transform(a_train)
a_test= pca.fit_transform(a_test)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion='entropy', random_state=0)
classifier.fit(a_train,b_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
b_pred = classifier.predict(a_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(b_test, b_pred)
print(cm)
accuracy_score(b_test, b_pred)
# Out:
# [[40  3  8]
#  [ 1 34  6]
#  [ 6  7 15]]
# 0.7416666666666667

# %%
import seaborn as sns

accuracy = accuracy_score(b_test, b_pred)
print(f"Accuracy: {accuracy:.2f}")

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=["zero", "one", "two"],
            yticklabels=["zero", "one", "two"])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f'Logistic Regression Confusion Matrix\nAccuracy: {accuracy:.2f}')
plt.tight_layout()
plt.show()
# Out:
# Accuracy: 0.74

# %%
from matplotlib.colors import ListedColormap


X_set, y_set = a_train, b_train
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=0.01),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=0.01))

plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green', 'blue')))

plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('red', 'green', 'blue'))(i), label=j)

plt.title('Logistic Regression (Training set)')
plt.xlabel('PCI')
plt.ylabel('PCZ')
plt.legend()
plt.show()
# Out:
# C:\Users\salil\AppData\Local\Temp\ipykernel_12668\3233172779.py:15: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
